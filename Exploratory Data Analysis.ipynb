# %% [markdown]
# ### Exploratory Data Analysis ~ EDA
# EDA is an approach to analyse the given data sets by summerizing their main characteristics with visualisations.
#
# Prerequisites:
# 1. Python Programming Language (<a href = "">Pandas</a> and <a href = "">Numpy</a>)
# 2. Mathematics

# %%
import pandas as pd
# pandas is a python library to deal with datasets (DataFrames and Series)

# %%
import numpy as np
# numpy stands for numeric python

# %%
import matplotlib.pyplot as plt

#matplotlib is a python library to plot a dataset in form of various graphs and visual informations.

# %%
df = pd.read_csv('chitest.csv', encoding = 'utf-8')

#here we read chitest.csv file using pandas library (csv files are comma seperated values) and made a dataframe called "df".

# %%
print(df)

#print statement prints the dataframe in a different manner as compared to the below visual shows.
# Out:
#    Gender Like Shopping?
# 0    Male             No
# 1  Female            Yes
# 2    Male            Yes
# 3  Female            Yes
# 4  Female            Yes
# 5    Male            Yes
# 6    Male             No
# 7  Female             No
# 8  Female             No

# %%
df

#dataframe
# Out:
#    Gender Like Shopping?
# 0    Male             No
# 1  Female            Yes
# 2    Male            Yes
# 3  Female            Yes
# 4  Female            Yes
# 5    Male            Yes
# 6    Male             No
# 7  Female             No
# 8  Female             No

# %%
contingency_table = pd.crosstab(df['Gender'], df['Like Shopping?'])
contingency_table

#crosstab is pandas functionality that accumulates the unique data in form of rows and columns and gives the corresponding values.
# Out:
# Like Shopping?  No  Yes
# Gender
# Female           2    3
# Male             2    2

# %%
from scipy import stats

#SciPy is a scientific library in python and basically a extension to numpy to perform more complex calculations in less time.

observed_values = contingency_table.values

# dataFrame.values return numpy representation of the dataset

print('Observed Values : ',observed_values)

b = stats.chi2_contingency(contingency_table)

Expected_table = b[3]

Expected_table
# Out:
# Observed Values :  [[2 3]
#  [2 2]]
# array([[2.22222222, 2.77777778],
#        [1.77777778, 2.22222222]])

# %% [markdown]
# ## NEW DATA SET ADDED

# %%
bd = pd.read_csv('bank.csv',sep = ';')
bd.head(10)
# We can pass argument in df.read(x), x will be the number of rows you want to see in output.
# Read the bank.csv file from my github repo, we will be applying Data Analysis on this file.
# Out:
#    age           job   marital  education default  balance housing loan  \
# 0   58    management   married   tertiary      no     2143     yes   no
# 1   44    technician    single  secondary      no       29     yes   no
# 2   33  entrepreneur   married  secondary      no        2     yes  yes
# 3   47   blue-collar   married    unknown      no     1506     yes   no
# 4   33       unknown    single    unknown      no        1      no   no
# 5   35    management   married   tertiary      no      231     yes   no
# 6   28    management    single   tertiary      no      447     yes  yes
# 7   42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 8   58       retired   married    primary      no      121     yes   no
# 9   43    technician    single  secondary      no      593     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# ...

# %%
bd['contact'].unique()

# bd['Column_Name'].unique() return the unique values in that particular column in form of a numpy array.
# Out:
# array(['unknown', 'cellular', 'telephone'], dtype=object)

# %%
bd.info()

# df.info() returns the column names there non-null count and data type as you can see in the output.

bd.describe()

# df.describe() returns statistics related to the dataframe like 
# standard deviation,  mean, count, min, max of a particular column.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB
# ...

# %%
bd.shape

#it outputs the number of rows per number of coulmns in a tuple form.
# Out:
# (45211, 17)

# %%
bd.columns.tolist()

#this returns a column list as output
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'balance',
#  'housing',
#  'loan',
#  'contact',
#  'day',
#  'month',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'y']

# %%
bd.age.unique()

#df.Column_name == df.['Column_name'] .unique() returns unique values in that particular column in form of an numpy array.
# Out:
# array([58, 44, 33, 47, 35, 28, 42, 43, 41, 29, 53, 57, 51, 45, 60, 56, 32,
#        25, 40, 39, 52, 46, 36, 49, 59, 37, 50, 54, 55, 48, 24, 38, 31, 30,
#        27, 34, 23, 26, 61, 22, 21, 20, 66, 62, 83, 75, 67, 70, 65, 68, 64,
#        69, 72, 71, 19, 76, 85, 63, 90, 82, 73, 74, 78, 80, 94, 79, 77, 86,
#        95, 81, 18, 89, 84, 87, 92, 93, 88])

# %%
bd.age.nunique()

#df.Column_name.nunique() returns number of unique value present in that particular column.
# Out:
# 77

# %%
bd.job.unique()
# Out:
# array(['management', 'technician', 'entrepreneur', 'blue-collar',
#        'unknown', 'retired', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student'], dtype=object)

# %%
bd.marital.unique()
# Out:
# array(['married', 'single', 'divorced'], dtype=object)

# %%
bd.education.unique()
# Out:
# array(['tertiary', 'secondary', 'unknown', 'primary'], dtype=object)

# %%
bd.isnull().sum()

# df.isnull() returns a boolean value corresponding to a particular row and column, 
# while if we use df.isnull().sum(), it returns number of null values count in a particular column.


# alternate method : using lambda function
# lambda function is an anonymous python that does not require any pre-definition before using it.
#bd.apply(lambda x : sum(x.isnull()), axis = 0)
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
bd.apply(lambda x : sum(x.isnull()), axis = 0)
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
bd.dtypes

# df.dtypes returns the data type of a all colums in a single frame.
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %% [markdown]
# Next we will be covering seaborn library in python, it is used widely in field of Machine Learning

# %% [markdown]
# ## Start : Seaborn
#
#
# Visit this link for detailed tutorial on seaborn library of pyhton.
#
# <a href = "">Seaborn</a> (Under Construction)

# %%
import seaborn as sns
import matplotlib.pyplot as plt                  # importing a library second time deals no effect on the execution
# %matplotlib inline


# %matplotlib inline sets the backend of matplotlib to the 'inline' backend

# %% [markdown]
# - Numerical Variables : Density plot, box plot
# - Numeric - Numeric : Scatter plot, pairwise density plot
# - Categorical data
# - Faceting in categorical data
# - Heatmaps

# %% [markdown]
# ### Single Numerical Column

# %%
# distplot : distribution plot, kde : kernel density estimate

sns.distplot(bd['age'],kde=True)
# if kde = True, y-axis will be probability density rather than count of "age" column.
# for age column mean and sigma will be calculated and the pdf will be calculated for all ages and plotted that is your smoothened distribution
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.distplot(bd['age'],kde=False)

# kde = False means the plot will be normal i.e. age vs count of age
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# There is a term coming in called **bins**.
#
# Bins are the grouping index(number of rectangular boxes plotted in the graph) on x-axis.
#
# Default value of bin is 50.
#
# Each bar corresponds to (Width of one rectangular box plotted in the graph on x-axis) = Range / Default bin value.

# %%
print("Minimum age in the data is : ", bd.age.min())
print("Maximum age in the data is : ", bd.age.max())
print("Range of age is from {} to {}, value is {}".format(bd.age.min(), bd.age.max(), bd.age.max()-bd.age.min()))
print("Default value of bin is 50, so each bar corresponds to the value of : ", (bd.age.max()-bd.age.min())/50)
# Out:
# Minimum age in the data is :  18
# Maximum age in the data is :  95
# Range of age is from 18 to 95, value is 77
# Default value of bin is 50, so each bar corresponds to the value of :  1.54

# %% [markdown]
# Above Plot Explaination...
#
# x-axis  :
#     - *to be continued....*

# %%
sns.distplot(bd.age, kde = False, hist = True, bins = 11, hist_kws = dict(edgecolor = 'k',linewidth = 1))
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.distplot(bd.age, kde = False, bins = [0,10,20,30,40,50,100], hist_kws = dict(edgecolor = 'g', linewidth = 2), color = 'green')

# We can change edge color of the boxes in distplot using hist_kws parameter which takes values in 
# dictionary format.

# We can change color of the boxes using color parameter in distplot method.
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.distplot(bd.age, kde = True, hist = False, bins = 30)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
# shade parameter will shade area under the curve (in kdeplot method only).

sns.kdeplot(bd.age, shade = True)
sns.kdeplot(bd.day, shade = True)
# Out:
# <AxesSubplot:>

# %%
myplot = sns.distplot(bd.age, kde = False, norm_hist = True, bins = 20)

myimg = myplot.get_figure()

#savefig function is used to save the image locally in the same folder as this jupyter file.

myimg.savefig('HistAge.jpg')

# %% [markdown]
# ### sns.boxplot()

# %%
#Quarter1 or Quartile 1 (25th percentile of the values in the selected column (like age in the below work))

# Q1(25) - (k)1.5(IQR) - lower whisker
# Q3(75) + (k)1.5(IQR) - upper whisker

# IQR : Interquartile range = Q3 - Q1

sns.boxplot(bd.age)

Q3 = bd.age.quantile(.75)
Q1 = bd.age.quantile(.25)

IQR = Q3 - Q1

median = bd.age.median()

print("Q1 value : ", Q1)
print("Median : ", median)
print("Q3 value : ", Q3)
print("IQR : ", IQR)
print("Upper Whisker Limit : ", (Q3 + 1.5*IQR))
print("Lower Whisker Limit : ", (Q1 - 1.5*IQR))
# Out:
# Q1 value :  33.0
# Median :  39.0
# Q3 value :  48.0
# IQR :  15.0
# Upper Whisker Limit :  70.5
# Lower Whisker Limit :  10.5

# %% [markdown]
# The two boundries like rotated 'T' (at 10.5 and 70.5 respectively), are the lower and upper whiskers respectively.
#
# Values beyond the upper whiskers are **OUTLIERS**, i.e. the data which is not of our use. (Abnormal data or incorrect data)
#
# The box represents Quartile 1(25th Percentile) to Median to Quartile 3(75th Percentile)

# %%
sns.boxplot(y='age',data = bd)

# sns.boxplot(x='age',data = bd) : default
# Out:
# <AxesSubplot:ylabel='age'>

# %% [markdown]
# ## Explain the distribution - Symmetric or Non-Symmetric

# %%
# boxplot can't identify the number of values for a given range i.e. distruibution plot
# to overcome this violinplot is introduced
# violinplot gives the outliers and whiskers, with the distribution plot.

sns.violinplot(bd.age) # default age on x-axis
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.violinplot(y='age', data=bd) # age on y-axis
# Out:
# <AxesSubplot:ylabel='age'>

# %% [markdown]
# ### numeric - numeric data points

# %% [markdown]
# We use jointplot to plot two numeric data points relation graph form the dataset.

# %%
sns.jointplot(x='age',y='balance',data=bd)

# this is a combination of scatter plot and histogram.

# %%
sns.jointplot(x='age',y='balance',data=bd.loc[(bd.balance>0)&(bd.balance<20000),:], kind='hex', height=10, color='g')

# kind = 'hex' gives density parameter
# As the density of the color increases, so will the data points.
# this also gives information about the overlapped data points, unlike previous jointplot

# %%
# linear model plot

sns.lmplot('age', 'balance', data=bd, order = 2) 

# this plot gives a line (according to the order) that can pass through maximum data point in the plot.

# %%
sns.lmplot('age','balance',data = bd,hue='default')

# hue parameter hepls to get insights from 3 columns simultaneous, in form of scatter plot.
# hue is for categorial variables only.

# default column represents the person, who have not paid their loans.

# %% [markdown]
# **Insights from the graph**
#  - Defaulters are having negative balances
#  - If a person is maintaing 0 Balance, loan should not be given to that person, but not always (in all cases).
#  - Defaulters are from 20-60 age group.

# %%
sns.lmplot('age', 'balance', data=bd, hue='housing')

# %% [markdown]
# **Insights from the graph**
#  - There are people with high balance but do not have a housing loan, so that could be our target field.
#  - Target area for the bank, or loan companies will be after 20,000 balance, having no housing loan.

# %%
# Above graph differentiated further in defaulter and non-defaulter columns.

sns.lmplot('age', 'balance', data=bd, hue='housing', col='default')

# %% [markdown]
# *Greater Insights*
#  - Target area is more precise now, with having default as 'no' and housing loan as 'no'.
#  - Banks can now target the customers from the first row having no housing loan and balance above 20k.

# %%
bd.loan.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
bd.default.value_counts()
# Out:
# no     44396
# yes      815
# Name: default, dtype: int64

# %%
sns.lmplot('age', 'balance', data=bd, hue='loan', col='default',row = 'housing')

# %% [markdown]
# More precise data for target audience is, where, housing = 'no' and default = 'no.

# %% [markdown]
# Starting with
# ### Categorical Data

# %%
bd.education.value_counts()
# Out:
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int64

# %%
bd.education.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='education', data= bd, hue='housing')
# Out:
# <AxesSubplot:xlabel='education', ylabel='count'>

# %% [markdown]
# **Insights**
#  - People having secondary education are more in number, so our upcoming target audience should be people with secondary education.
#  - Proportion of housing loan between yes and no is more in secondary education than other educations.
#  - If we put more efforts on secondary educated people, thier is high chances that the person may take a loan.

# %%
sns.countplot(x='education', data= bd, hue='default')
# Out:
# <AxesSubplot:xlabel='education', ylabel='count'>

# %%
sns.countplot(y='education', data= bd, hue='loan')
# Out:
# <AxesSubplot:xlabel='count', ylabel='education'>

# %% [markdown]
# Insights
#  - Secondary educated people are taking more loans as compared to other educations.
#  - If we target blue line people from secondary education, thier are high chances of conversion.

# %% [markdown]
# ## Numeric - Categorical

# %%
#sns.boxplot(x='age', data=bd)

sns.boxplot(x='balance', y='marital', data=bd)
# Out:
# <AxesSubplot:xlabel='balance', ylabel='marital'>

# %% [markdown]
# # Heatmaps

# %% [markdown]
# ### Correlation :

# %% [markdown]
# #### Correlation coefficient are used in statistics to measure how strong a relationship is between two matrices. There are several types of correlation coefficient:
#
# ##### Pearson's Coefficient (Also called Pearon's R) is a correlation coefficient commonly used in linear regression.
#
# ###### Correlation coefficients formulas are used to find how strong a relationship is bewteen data. The formulas return a value between -1 to 1, where:
#
# _1 indicates a positive (+) relationship._
#
# _-1 indicates a negative (-) relationship._
#
# _0 indicates no relationship._

# %% [markdown]
# ![Formula and Graph](images/heatmap.png)

# %%
#measuring the correlation between the data.

bd.corr()
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.097783 -0.009120 -0.004648  0.004760 -0.023758  0.001288
# balance   0.097783  1.000000  0.004503  0.021560 -0.014578  0.003435  0.016674
# day      -0.009120  0.004503  1.000000 -0.030206  0.162490 -0.093044 -0.051710
# duration -0.004648  0.021560 -0.030206  1.000000 -0.084570 -0.001565  0.001203
# campaign  0.004760 -0.014578  0.162490 -0.084570  1.000000 -0.088628 -0.032855
# pdays    -0.023758  0.003435 -0.093044 -0.001565 -0.088628  1.000000  0.454820
# previous  0.001288  0.016674 -0.051710  0.001203 -0.032855  0.454820  1.000000

# %% [markdown]
# Leading diagonal's value is 1 as the same variables are highly correlated.

# %%
sns.heatmap(bd.corr())
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(bd)

# all columns vs all columns

# not a good plot to get insights from the data

# %% [markdown]
# ### Methods to pre-process Outliers in the data
#
# **Outliers** : In statistics, an outliers is an observation point that is distant from the other observations.
#
# **IQR**
#
# The InterQuartile Range (IQR), also called midspread or middle 50%, or technically H-spread, is a measure of statistical dispersion, being equal to the difference between 75th and 25th percentiles, or between upper and lower quartiles. **IQR = Q3 - Q1**. In other words, the IQR is the first quartile subtracted from the third quartile; These quartiles can be clearly seen on the box plot on the data. It is a measure of the dispersion, similar to standard deviation or variance, but is much more robust against outliers.

# %%
bd.age.median()
# Out:
# 39.0

# %%
sns.boxplot(bd.age)

# or alternate syntax : sns.boxplot(data=bd,x='age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
Q1 = bd.age.quantile(0.25)
print(Q1)
Q3 = bd.age.quantile(0.75)
print(Q3)
IQR = Q3 - Q1
print(IQR)
print(Q1 - (1.5 * IQR))
print(Q3 + (1.5 * IQR))
# Out:
# 33.0
# 48.0
# 15.0
# 10.5
# 70.5

# %%
bd[~((bd.age < (Q1 - 1.5 * IQR)) | (bd.age > (Q3 + 1.5 * IQR)))].age.median()
# Out:
# 39.0

# %% [markdown]
# **1. Mean / Median or Random Imputation**
#
# If we have a reason to believe that outliers are due to mechanical errors or problems during measurement. That means, the outliers are in nature similar to missing data, then any method used for missing data imputation can be used to replace outliers. The number of outliers are small (otherwise they won't be called outliers) and it's reasonable to use mean / median / random imputation to replace them.

# %% [markdown]
# _Replacing the Outliers with median_

# %%
median = bd.loc[bd.age < 70, 'age'].median()
median
# Out:
# 39.0

# %%
bd.loc[bd.age > 70, 'age'] = median

# %%
sns.boxplot(bd.age)

# outliers replaced with the median
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# In the same way, we can replace it with mean.

# %% [markdown]
#  **2. Trimming**
#
#  In this method, we discard the outliers completely. That is, eliminate the data points that are considered as outliers. In situations where you won't be removing large number of values from the dataset.
#
#  Trimming is a good and fast approach.

# %%
index = bd[bd.age > 60].index
bd.drop(index, inplace = True)

# %%
sns.boxplot(x = bd.age)
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# **3. Top bottom zero coding**
#
# Top coding means caping the maximum of the distribution at an arbitrary set value. A top coded variable is one for which data points above an upper bound are censored. By implementing top coding, the outlier is capped at a certain maximum value and looks like many other observations. Bottom coding is analogous but on the left side of the distribution. That is, all the values below a certain threshold, are capped to that threshold. If the threshold is zero, then it is known as zero coding. For example, for variable like 'age' or 'earnings', it is not possible to have negative values. Thus, it's reasonable to cap the lowest value to zero.

# %%
print('age > 55 : {}'.format(bd[bd.age>55].shape[0]))
print('percentage of outliers : {}'.format(bd[bd.age>55].shape[0]/np.float(bd.shape[0])))
# Out:
# age > 55 : 3712
# percentage of outliers : 0.08339698944057515

# %%
bd.loc[bd.age>55,'age'] = 50
bd.age.max()
# Out:
# 55.0

# %% [markdown]
# **4. Discretization**
#
# It is the process of transforming continuous variables into discrete variables by creating a set of contiguous intervals that spans the range of variable's value. Thus, these outliers observations no longer differ from the rest of the values at the tails of the distribution, as they are now all together in the same interval/bucket. There are several approaches to transform continuous variables into discrete ones. This process is also known as binning, with each bin being each interval.

# %%
list(range(15, 86, 5))
# Out:
# [15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80, 85]

# %%
ages = ['15-19', '20-24', '25-29', '30-34', '35-39', '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70-74', '75-79','80-84']
bd['age_group'] = pd.cut(bd.age, range(15, 86, 5), right = False, labels = ages)
bd[['age','age_group']].head(15)
# Out:
#      age age_group
# 0   50.0     50-54
# 1   44.0     40-44
# 2   33.0     30-34
# 3   47.0     45-49
# 4   33.0     30-34
# 5   35.0     35-39
# 6   28.0     25-29
# 7   42.0     40-44
# 8   50.0     50-54
# 9   43.0     40-44
# 10  41.0     40-44
# 11  29.0     25-29
# 12  53.0     50-54
# 13  50.0     50-54
# 14  50.0     50-54

# %%
bd.age_group.value_counts()
# Out:
# 30-34    9740
# 35-39    8836
# 50-54    8200
# 40-44    6185
# 45-49    5470
# 25-29    4464
# 55-59     806
# 20-24     762
# 15-19      47
# 80-84       0
# 75-79       0
# 70-74       0
# 65-69       0
# 60-64       0
# Name: age_group, dtype: int64

# %% [markdown]
# **List of Techniques**
#  - Imputation
#  - Binning
#  - Log transform, Scaling
#  - One-Hot Encoding
#  - Grouping Operations
#  - Feature Split

# %% [markdown]
# ### Imputation
#
# There are many options we could consider when replacing a missing value, for example
#
# 1. A constant value that has meaning with the domain, such as 0, distinct from all other values.
# 2. A value from another randomly selected record.
# 3. A mean, median or mode value for the column.
# 4. A value estimated by another predictive model.

# %% [markdown]
# ### https://machinelearningmastery.com/handle-missing-data-python/

# %%
pd.cut(np.array([1,12,5,4,6,4,9]),4, labels=['bad','medium','good','best'])
# Out:
# ['bad', 'best', 'medium', 'medium', 'medium', 'medium', 'good']
# Categories (4, object): ['bad' < 'medium' < 'good' < 'best']

# %%
# one-hot encoding

df_2 = pd.DataFrame({'A' : ['a','b','a'],'B' : ['b','a','c'],'C':[1,2,3]}) 

print(df_2)
pd.get_dummies(df_2)
# Out:
#    A  B  C
# 0  a  b  1
# 1  b  a  2
# 2  a  c  3
#    C  A_a  A_b  B_a  B_b  B_c
# 0  1    1    0    0    1    0
# 1  2    0    1    1    0    0
# 2  3    1    0    0    0    1

# %%
print(df_2)

df_2.iloc[0,1]
# Out:
#    A  B  C
# 0  a  b  1
# 1  b  a  2
# 2  a  c  3
# 'b'

# %% [markdown]
# Some articles, useful links on EDA
#
# https://medium.com/@srivathsagottipati/exploratory-data-analysis-eda-4b81d84ef5cf
#
# https://github.com/cmawer/pycon-2017-eda-tutorial/blob/master/EDA-cheat-sheet.md

# %% [markdown]
# More updates will be there in coming days...
